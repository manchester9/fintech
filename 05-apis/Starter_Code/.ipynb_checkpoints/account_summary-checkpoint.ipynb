# %%
import os
import plaid
import requests
import datetime
import json
import pandas as pd
# %matplotlib inline
import tabulate

# %%
def pretty_print_response(response):
  print(json.dumps(response, indent=4, sort_keys=True))

# %%
PLAID_CLIENT_ID = os.getenv('PLAID_CLIENT_ID')
PLAID_SECRET = os.getenv('PLAID_SECRET')
PLAID_PUBLIC_KEY = os.getenv('PLAID_PUBLIC_KEY')
PLAID_ENV = os.getenv('PLAID_ENV', 'sandbox')
PLAID_PRODUCTS = os.getenv('PLAID_PRODUCTS', 'transactions')

# %%
type(PLAID_CLIENT_ID)
# Out:
# str

# %%
PLAID_CLIENT_ID
# Out:
# '5d7d1f362dd19f001492b690'

# %%
type(PLAID_PRODUCTS)
# Out:
# str

# %% [markdown]
# # Plaid Access Token
#
# In this section, you will use the plaid-python api to generate the correct authentication tokens to access data in the free developer Sandbox. This mimics how you might connect to your own account or a customer account, but due to privacy issues, this homework will only require connecting to and analyzing the fake data from the developer sandbox that Plaid provides.
#
# Complete the following steps to generate an access token:
# 1. Create a client to connect to paid
# 2. Use the client to generate a public token and request the following items:
# ['transactions', 'income', 'assets']
# 3. Exchange the public token for an access token
# 4. Test the access token by requesting and printing the available test accounts

# %% [markdown]
# ### 1. Create a client to connect to plaid

# %%
INSITUTION_ID = "ins_109508"

# %%
# YOUR CODE HERE
client = plaid.Client(client_id=PLAID_CLIENT_ID, secret=PLAID_SECRET, public_key=PLAID_PUBLIC_KEY, environment='sandbox')

# %%
# Listing all the client object methods
object_methods = [method_name for method_name in dir(client)
                  if callable(getattr(client, method_name))]
# object_methods

# %%
institution_list = client.Institutions.get(6)

# %%
type(institution_list)

# Output to institution list to file
# import csv
# w = csv.writer(open('institution_list.csv', "w"))
# for key, val in institution_list.items():
#     w.writerow([key, val])
    
# institution_list
# Out:
# dict

# %%
institution_list['institutions'][5]

# for key, value in institution_list.items():
#     #print value
#     print(key, len([item for item in value]))
# Out:
# {'country_codes': ['US'],
#  'credentials': [{'label': 'Username', 'name': 'username', 'type': 'text'},
#   {'label': 'Password', 'name': 'password', 'type': 'password'}],
#  'has_mfa': False,
#  'input_spec': 'fixed',
#  'institution_id': 'ins_100866',
#  'mfa': [],
#  'mfa_code_type': 'numeric',
#  'name': 'Bank of America - Charitable Gift Fund',
#  'products': ['assets', 'balance', 'transactions'],
#  'routing_numbers': []}

# %% [markdown]
# ### 2. Generate a public token

# %%
# YOUR CODE HERE
create_tkn_response = client.Sandbox.public_token.create(INSITUTION_ID, ['transactions','income','assets'])

# %% [markdown]
# ### 3. Exchange the public token for an access token

# %%
# YOUR CODE HERE
exchange_response = client.Item.public_token.exchange(create_tkn_response['public_token'])

# Store access token as variable
access_token = exchange_response['access_token']

# %% [markdown]
# ### 4. Fetch Accounts

# %%
# YOUR CODE HERE
fetch_accounts = client.Accounts.get(access_token)
fetch_accounts['accounts'][0]
# Out:
# {'account_id': 'voVWnJblXpfKylGrwXoASV13BpaB3JfWMeJjn',
#  'balances': {'available': 100,
#   'current': 110,
#   'iso_currency_code': 'USD',
#   'limit': None,
#   'unofficial_currency_code': None},
#  'mask': '0000',
#  'name': 'Plaid Checking',
#  'official_name': 'Plaid Gold Standard 0% Interest Checking',
#  'subtype': 'checking',
#  'type': 'depository'}

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Roland.Ferrao\\Desktop\\Desktop\\Clients\\Knowledge repo\\Columbia fintech\\Fintech\\fintech\\05-apis\\Starter_Code'

# %%
# Output to file
# import csv
# w = csv.writer(open('fetch_accounts.csv', "w"))
# for key, val in fetch_accounts.items():
#     w.writerow([key, val])

# %% [markdown]
# # Account Transactions with Plaid
#
# In this section, you will use the Plaid Python SDK to connect to the Developer Sandbox account and grab a list of transactions. You will need to complete the following steps:
#
#
# 1. Use the access token to fetch the transactions for the last 90 days
# 2. Print the categories for each transaction type
# 3. Create a new DataFrame using the following fields from the JSON transaction data: `date, name, amount, category`. (For categories with more than one label, just use the first category label in the list)
# 4. Convert the data types to the appropriate types (i.e. datetimeindex for the date and float for the amount)

# %% [markdown]
# ### 1. Fetch the Transactions for the last 90 days

# %%
# YOUR CODE HERE
start_date = '{:%Y-%m-%d}'.format(datetime.datetime.now() + datetime.timedelta(-90))
end_date = '{:%Y-%m-%d}'.format(datetime.datetime.now())

# Get transactions for date range
transaction_response = client.Transactions.get(access_token,start_date,end_date)

# %%
type(transaction_response)
transaction_response['transactions'][0]
transaction_response
# Out:
# {'accounts': [{'account_id': 'voVWnJblXpfKylGrwXoASV13BpaB3JfWMeJjn',
#    'balances': {'available': 100,
#     'current': 110,
#     'iso_currency_code': 'USD',
#     'limit': None,
#     'unofficial_currency_code': None},
#    'mask': '0000',
#    'name': 'Plaid Checking',
#    'official_name': 'Plaid Gold Standard 0% Interest Checking',
#    'subtype': 'checking',
#    'type': 'depository'},
#   {'account_id': 'RpgyDAJG3RhdpVneL6m8ceymLBJLmMFRgkMKG',
#    'balances': {'available': 200,
#     'current': 210,
#     'iso_currency_code': 'USD',
#     'limit': None,
#     'unofficial_currency_code': None},
#    'mask': '1111',
#    'name': 'Plaid Saving',
#    'official_name': 'Plaid Silver Standard 0.1% Interest Saving',
#    'subtype': 'savings',
#    'type': 'depository'},
#   {'account_id': '6GWbE4JvlotAlJMRGPwXs9alrN8rl3ugBKkWG',
#    'balances': {'available': None,
#     'current': 1000,
#     'iso_currency_code': 'USD',
#     'limit': None,
#     'unofficial_currency_code': None},
#    'mask': '2222',
#    'name': 'Plaid CD',
#    'official_name': 'Plaid Bronze Standard 0.2% Interest CD',
#    'subtype': 'cd',
#    'type': 'depository'},
#   {'account_id': 'XAnVWRprPzf78QaPkd6VIGmJ7aB7J5fdmjJ49',
#    'balances': {'available': None,
#     'current': 410,
#     'iso_currency_code': 'USD',
#     'limit': 2000,
#     'unofficial_currency_code': None},
#    'mask': '3333',
#    'name': 'Plaid Credit Card',
#    'official_name': 'Plaid Diamond 12.5% APR Interest Credit Card',
#    'subtype': 'credit card',
#    'type': 'credit'},
#   {'account_id': 'DkazDGKB7xfbVdo7nxpXU5mDqrNqD8uv5RdgZ',
#    'balances': {'available': 43200,
#     'current': 43200,
#     'iso_currency_code': 'USD',
#     'limit': None,
#     'unofficial_currency_code': None},
#    'mask': '4444',
#    'name': 'Plaid Money Market',
#    'official_name': 'Plaid Platinum Standard 1.85% Interest Money Market',
#    'subtype': 'money market',
#    'type': 'depository'},
#   {'account_id': 'VEAyDmoq4lsPga36vj4wUD68yrBy8RFWByl4l',
#    'balances': {'available': None,
#     'current': 320.76,
#     'iso_currency_code': 'USD',
#     'limit': None,
#     'unofficial_currency_code': None},
#    'mask': '5555',
#    'name': 'Plaid IRA',
#    'official_name': None,
#    'subtype': 'ira',
#    'type': 'investment'},
#   {'account_id': 'wkVXm1DqEgfyZRnbBgdxIw13RVjR3LhrbRMvK',
#    'balances': {'available': None,
#     'current': 23631.9805,
#     'iso_currency_code': 'USD',
#     'limit': None,
#     'unofficial_currency_code': None},
#    'mask': '6666',
#    'name': 'Plaid 401k',
#    'official_name': None,
#    'subtype': '401k',
#    'type': 'investment'},
#   {'account_id': '5AEMmaz5pLfAmVBXQl6Js3aQp8RpQgSZ1yJoL',
#    'balances': {'available': None,
#     'current': 65262,
#     'iso_currency_code': 'USD',
#     'limit': None,
#     'unofficial_currency_code': None},
#    'mask': '7777',
#    'name': 'Plaid Student Loan',
#    'official_name': None,
#    'subtype': 'student',
#    'type': 'loan'}],
#  'item': {'available_products': ['auth',
#    'balance',
#    'credit_details',
#    'identity',
#    'investments',
#    'liabilities'],
#   'billed_products': ['assets', 'income', 'transactions'],
#   'error': None,
#   'institution_id': 'ins_109508',
#   'item_id': 'P1pZDAR7zmh3pE6XJw1eHzj5o1L3xdC7DZnBj',
#   'webhook': ''},
#  'request_id': 'PrRMNR8Bbfnsrl9',
#  'total_transactions': 48,
#  'transactions': [{'account_id': 'XAnVWRprPzf78QaPkd6VIGmJ7aB7J5fdmjJ49',
#    'account_owner': None,
#    'amount': 500,
#    'category': ['Food and Drink', 'Restaurants'],
#    'category_id': '13005000',
#    'date': '2019-09-28',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'Tectra Inc',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': 'rMVWnoXwEjcZD98X1obyI47JepzynmflkVGQ5',
#    'transaction_type': 'place',
#    'unofficial_currency_code': None},
#   {'account_id': 'XAnVWRprPzf78QaPkd6VIGmJ7aB7J5fdmjJ49',
#    'account_owner': None,
#    'amount': 2078.5,
#    'category': ['Payment'],
#    'category_id': '16000000',
#    'date': '2019-09-27',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'AUTOMATIC PAYMENT - THANK',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': '3EgXAxVJ1Qs1DE5nmrzGSWPQ4qVAx7HqVeWAj',
#    'transaction_type': 'special',
#    'unofficial_currency_code': None},
#   {'account_id': 'XAnVWRprPzf78QaPkd6VIGmJ7aB7J5fdmjJ49',
#    'account_owner': None,
#    'amount': 500,
#    'category': ['Food and Drink', 'Restaurants'],
#    'category_id': '13005000',
#    'date': '2019-09-27',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'KFC',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': 'BBxKbWNkPrHjdZ91KqvAszGLJmEA3qCwxNkBB',
#    'transaction_type': 'place',
#    'unofficial_currency_code': None},
#   {'account_id': 'XAnVWRprPzf78QaPkd6VIGmJ7aB7J5fdmjJ49',
#    'account_owner': None,
#    'amount': 500,
#    'category': ['Shops', 'Sporting Goods'],
#    'category_id': '19046000',
#    'date': '2019-09-27',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'Madison Bicycle Shop',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': 'zWqwX1BzKnuy7DBgndjzIvgl5LjzxBtoX1eV9',
#    'transaction_type': 'place',
#    'unofficial_currency_code': None},
#   {'account_id': 'RpgyDAJG3RhdpVneL6m8ceymLBJLmMFRgkMKG',
#    'account_owner': None,
#    'amount': 25,
#    'category': ['Payment', 'Credit Card'],
#    'category_id': '16001000',
#    'date': '2019-09-18',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'CREDIT CARD 3333 PAYMENT *//',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': 'lPVQnogAEqIDgqMRymwxfQxm5PMajXsZmeM43',
#    'transaction_type': 'special',
#    'unofficial_currency_code': None},
#   {'account_id': 'voVWnJblXpfKylGrwXoASV13BpaB3JfWMeJjn',
#    'account_owner': None,
#    'amount': 5.4,
#    'category': ['Travel', 'Car Service', 'Ride Share'],
#    'category_id': '22006001',
#    'date': '2019-09-18',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'Uber 063015 SF**POOL**',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': 'DkazDGKB7xfbVdo7nxpXU5mDeEGypNCvLBZ1Q',
#    'transaction_type': 'special',
#    'unofficial_currency_code': None},
#   {'account_id': 'DkazDGKB7xfbVdo7nxpXU5mDqrNqD8uv5RdgZ',
#    'account_owner': None,
#    'amount': 5850,
#    'category': ['Transfer', 'Debit'],
#    'category_id': '21006000',
#    'date': '2019-09-17',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'ACH Electronic CreditGUSTO PAY 123456',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': 'ACH',
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': 'aqVrbGJ7posdpNxoeJPlcL8J5pDlGVi7KxXNw',
#    'transaction_type': 'special',
#    'unofficial_currency_code': None},
#   {'account_id': '6GWbE4JvlotAlJMRGPwXs9alrN8rl3ugBKkWG',
#    'account_owner': None,
#    'amount': 1000,
#    'category': ['Transfer', 'Deposit'],
#    'category_id': '21007000',
#    'date': '2019-09-17',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'CD DEPOSIT .INITIAL.',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': 'K7QNDWwPkpHq6kr7mLbvSRP58Lk43KfVDa5yv',
#    'transaction_type': 'special',
#    'unofficial_currency_code': None},
#   {'account_id': 'XAnVWRprPzf78QaPkd6VIGmJ7aB7J5fdmjJ49',
#    'account_owner': None,
#    'amount': 78.5,
#    'category': ['Recreation', 'Gyms and Fitness Centers'],
#    'category_id': '17018000',
#    'date': '2019-09-16',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'Touchstone Climbing',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': 'x8VWnmLKlEhzGqb5jvnxclmW3N6KBACnKRQ17',
#    'transaction_type': 'place',
#    'unofficial_currency_code': None},
#   {'account_id': 'voVWnJblXpfKylGrwXoASV13BpaB3JfWMeJjn',
#    'account_owner': None,
#    'amount': -500,
#    'category': ['Travel', 'Airlines and Aviation Services'],
#    'category_id': '22001000',
#    'date': '2019-09-16',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'United Airlines',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': 'VEAyDmoq4lsPga36vj4wUD68kPl9ABfWZXDaE',
#    'transaction_type': 'special',
#    'unofficial_currency_code': None},
#   {'account_id': 'voVWnJblXpfKylGrwXoASV13BpaB3JfWMeJjn',
#    'account_owner': None,
#    'amount': 12,
#    'category': ['Food and Drink', 'Restaurants'],
#    'category_id': '13005000',
#    'date': '2019-09-15',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': '3322'},
#    'name': "McDonald's",
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': 'wkVXm1DqEgfyZRnbBgdxIw13bMgmWjur1xQG1',
#    'transaction_type': 'place',
#    'unofficial_currency_code': None},
#   {'account_id': 'voVWnJblXpfKylGrwXoASV13BpaB3JfWMeJjn',
#    'account_owner': None,
#    'amount': 4.33,
#    'category': ['Food and Drink', 'Restaurants', 'Coffee Shop'],
#    'category_id': '13005043',
#    'date': '2019-09-15',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'Starbucks',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': '5AEMmaz5pLfAmVBXQl6Js3aQdvG9yRUZQA6vX',
#    'transaction_type': 'place',
#    'unofficial_currency_code': None},
#   {'account_id': 'voVWnJblXpfKylGrwXoASV13BpaB3JfWMeJjn',
#    'account_owner': None,
#    'amount': 89.4,
#    'category': ['Food and Drink', 'Restaurants'],
#    'category_id': '13005000',
#    'date': '2019-09-14',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'SparkFun',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': 'JjeNDWdVL1Ilm671Wxj8ivVLjmp8NdtdevnAM',
#    'transaction_type': 'place',
#    'unofficial_currency_code': None},
#   {'account_id': 'RpgyDAJG3RhdpVneL6m8ceymLBJLmMFRgkMKG',
#    'account_owner': None,
#    'amount': -4.22,
#    'category': ['Transfer', 'Credit'],
#    'category_id': '21005000',
#    'date': '2019-09-13',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'INTRST PYMNT',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': 'qZV1yo5AwNHoAbgjy4DXI8JpzD6XZ4Cdy1QEz',
#    'transaction_type': 'special',
#    'unofficial_currency_code': None},
#   {'account_id': 'XAnVWRprPzf78QaPkd6VIGmJ7aB7J5fdmjJ49',
#    'account_owner': None,
#    'amount': 500,
#    'category': ['Travel', 'Airlines and Aviation Services'],
#    'category_id': '22001000',
#    'date': '2019-09-03',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'United Airlines',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': 'dzV369eZEGHlK64b8wNEiKywMvorAXHZnxXkN',
#    'transaction_type': 'special',
#    'unofficial_currency_code': None},
#   {'account_id': 'voVWnJblXpfKylGrwXoASV13BpaB3JfWMeJjn',
#    'account_owner': None,
#    'amount': 6.33,
#    'category': ['Travel', 'Car Service', 'Ride Share'],
#    'category_id': '22006001',
#    'date': '2019-09-01',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'Uber 072515 SF**POOL**',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': 'kN5QWoXAEJIMdmVLRADGHnJAGWEdzBfW1em96',
#    'transaction_type': 'special',
#    'unofficial_currency_code': None},
#   {'account_id': 'XAnVWRprPzf78QaPkd6VIGmJ7aB7J5fdmjJ49',
#    'account_owner': None,
#    'amount': 500,
#    'category': ['Food and Drink', 'Restaurants'],
#    'category_id': '13005000',
#    'date': '2019-08-29',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'Tectra Inc',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': 'Az3kEW5KNqHA5wxm1nvEsj69wRelmyF1QJMa6',
#    'transaction_type': 'place',
#    'unofficial_currency_code': None},
#   {'account_id': 'XAnVWRprPzf78QaPkd6VIGmJ7aB7J5fdmjJ49',
#    'account_owner': None,
#    'amount': 2078.5,
#    'category': ['Payment'],
#    'category_id': '16000000',
#    'date': '2019-08-28',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'AUTOMATIC PAYMENT - THANK',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': 'WWGyDAwkNKu68zZbGEnJuo5mA47VZ1ilkyxXP',
#    'transaction_type': 'special',
#    'unofficial_currency_code': None},
#   {'account_id': 'XAnVWRprPzf78QaPkd6VIGmJ7aB7J5fdmjJ49',
#    'account_owner': None,
#    'amount': 500,
#    'category': ['Food and Drink', 'Restaurants'],
#    'category_id': '13005000',
#    'date': '2019-08-28',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'KFC',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': 'Ed4BDWR3eaIG7gBLKnEJTGe7Bb1mNqIXqezr4',
#    'transaction_type': 'place',
#    'unofficial_currency_code': None},
#   {'account_id': 'XAnVWRprPzf78QaPkd6VIGmJ7aB7J5fdmjJ49',
#    'account_owner': None,
#    'amount': 500,
#    'category': ['Shops', 'Sporting Goods'],
#    'category_id': '19046000',
#    'date': '2019-08-28',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'Madison Bicycle Shop',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': '8bGjEP4ZKWhrLV7MReBZc1WZJx9kBvIwbp5gw',
#    'transaction_type': 'place',
#    'unofficial_currency_code': None},
#   {'account_id': 'RpgyDAJG3RhdpVneL6m8ceymLBJLmMFRgkMKG',
#    'account_owner': None,
#    'amount': 25,
#    'category': ['Payment', 'Credit Card'],
#    'category_id': '16001000',
#    'date': '2019-08-19',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'CREDIT CARD 3333 PAYMENT *//',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': 'aqVrbGJ7posdpNxoeJPlcL8x56BAmWf7BJnky',
#    'transaction_type': 'special',
#    'unofficial_currency_code': None},
#   {'account_id': 'voVWnJblXpfKylGrwXoASV13BpaB3JfWMeJjn',
#    'account_owner': None,
#    'amount': 5.4,
#    'category': ['Travel', 'Car Service', 'Ride Share'],
#    'category_id': '22006001',
#    'date': '2019-08-19',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'Uber 063015 SF**POOL**',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': 'oeVmnoZyExik95p4owyLUD1vdo8MENCRd5AoJ',
#    'transaction_type': 'special',
#    'unofficial_currency_code': None},
#   {'account_id': 'DkazDGKB7xfbVdo7nxpXU5mDqrNqD8uv5RdgZ',
#    'account_owner': None,
#    'amount': 5850,
#    'category': ['Transfer', 'Debit'],
#    'category_id': '21006000',
#    'date': '2019-08-18',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'ACH Electronic CreditGUSTO PAY 123456',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': 'ACH',
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': '3EgXAxVJ1Qs1DE5nmrzGSWPG4vwlgEIqDbXWg',
#    'transaction_type': 'special',
#    'unofficial_currency_code': None},
#   {'account_id': '6GWbE4JvlotAlJMRGPwXs9alrN8rl3ugBKkWG',
#    'account_owner': None,
#    'amount': 1000,
#    'category': ['Transfer', 'Deposit'],
#    'category_id': '21007000',
#    'date': '2019-08-18',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'CD DEPOSIT .INITIAL.',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': 'yElWnR9rqAsB76bDgXLWFgEvznG31KsyznMWd',
#    'transaction_type': 'special',
#    'unofficial_currency_code': None},
#   {'account_id': 'XAnVWRprPzf78QaPkd6VIGmJ7aB7J5fdmjJ49',
#    'account_owner': None,
#    'amount': 78.5,
#    'category': ['Recreation', 'Gyms and Fitness Centers'],
#    'category_id': '17018000',
#    'date': '2019-08-17',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'Touchstone Climbing',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': 'gxVaW6w79vHNyqjdakzGfr6joqv9pmugxR9Pl',
#    'transaction_type': 'place',
#    'unofficial_currency_code': None},
#   {'account_id': 'voVWnJblXpfKylGrwXoASV13BpaB3JfWMeJjn',
#    'account_owner': None,
#    'amount': -500,
#    'category': ['Travel', 'Airlines and Aviation Services'],
#    'category_id': '22001000',
#    'date': '2019-08-17',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'United Airlines',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': 'pQVRnmbAwaFkgJo4ed1bU7mvZAlrW5hLZjepy',
#    'transaction_type': 'special',
#    'unofficial_currency_code': None},
#   {'account_id': 'voVWnJblXpfKylGrwXoASV13BpaB3JfWMeJjn',
#    'account_owner': None,
#    'amount': 12,
#    'category': ['Food and Drink', 'Restaurants'],
#    'category_id': '13005000',
#    'date': '2019-08-16',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': '3322'},
#    'name': "McDonald's",
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': '1gpMEBrWZPio6g5vd83lIKBljMQmLrs58XVpE',
#    'transaction_type': 'place',
#    'unofficial_currency_code': None},
#   {'account_id': 'voVWnJblXpfKylGrwXoASV13BpaB3JfWMeJjn',
#    'account_owner': None,
#    'amount': 4.33,
#    'category': ['Food and Drink', 'Restaurants', 'Coffee Shop'],
#    'category_id': '13005043',
#    'date': '2019-08-16',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'Starbucks',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': 'LeZNDwGPlgiKXgxwDqaZSvP384GA5dfPXKBkz',
#    'transaction_type': 'place',
#    'unofficial_currency_code': None},
#   {'account_id': 'voVWnJblXpfKylGrwXoASV13BpaB3JfWMeJjn',
#    'account_owner': None,
#    'amount': 89.4,
#    'category': ['Food and Drink', 'Restaurants'],
#    'category_id': '13005000',
#    'date': '2019-08-15',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'SparkFun',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': 'MQMNDV9PqEFrzJVZ6BdkcnNbxk1JraC9JpkLk',
#    'transaction_type': 'place',
#    'unofficial_currency_code': None},
#   {'account_id': 'RpgyDAJG3RhdpVneL6m8ceymLBJLmMFRgkMKG',
#    'account_owner': None,
#    'amount': -4.22,
#    'category': ['Transfer', 'Credit'],
#    'category_id': '21005000',
#    'date': '2019-08-14',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'INTRST PYMNT',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': 'dzV369eZEGHlK64b8wNEiKy4Mbjl1PsZjz9BL',
#    'transaction_type': 'special',
#    'unofficial_currency_code': None},
#   {'account_id': 'XAnVWRprPzf78QaPkd6VIGmJ7aB7J5fdmjJ49',
#    'account_owner': None,
#    'amount': 500,
#    'category': ['Travel', 'Airlines and Aviation Services'],
#    'category_id': '22001000',
#    'date': '2019-08-04',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'United Airlines',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': 'oeVmnoZyExik95p4owyLUD1vdo8MENCRd5A14',
#    'transaction_type': 'special',
#    'unofficial_currency_code': None},
#   {'account_id': 'voVWnJblXpfKylGrwXoASV13BpaB3JfWMeJjn',
#    'account_owner': None,
#    'amount': 6.33,
#    'category': ['Travel', 'Car Service', 'Ride Share'],
#    'category_id': '22006001',
#    'date': '2019-08-02',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'Uber 072515 SF**POOL**',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': 'ZnVyWAwB7dHQpylX1NrEsqblLoBxJgIg6mWex',
#    'transaction_type': 'special',
#    'unofficial_currency_code': None},
#   {'account_id': 'XAnVWRprPzf78QaPkd6VIGmJ7aB7J5fdmjJ49',
#    'account_owner': None,
#    'amount': 500,
#    'category': ['Food and Drink', 'Restaurants'],
#    'category_id': '13005000',
#    'date': '2019-07-30',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'Tectra Inc',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': 'pQVRnmbAwaFkgJo4ed1bU7mvZAlrW5hLZjeb6',
#    'transaction_type': 'place',
#    'unofficial_currency_code': None},
#   {'account_id': 'XAnVWRprPzf78QaPkd6VIGmJ7aB7J5fdmjJ49',
#    'account_owner': None,
#    'amount': 2078.5,
#    'category': ['Payment'],
#    'category_id': '16000000',
#    'date': '2019-07-29',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'AUTOMATIC PAYMENT - THANK',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': 'LeZNDwGPlgiKXgxwDqaZSvP384GA5dfPXKBqm',
#    'transaction_type': 'special',
#    'unofficial_currency_code': None},
#   {'account_id': 'XAnVWRprPzf78QaPkd6VIGmJ7aB7J5fdmjJ49',
#    'account_owner': None,
#    'amount': 500,
#    'category': ['Food and Drink', 'Restaurants'],
#    'category_id': '13005000',
#    'date': '2019-07-29',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'KFC',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': '1gpMEBrWZPio6g5vd83lIKBljMQmLrs58XVN1',
#    'transaction_type': 'place',
#    'unofficial_currency_code': None},
#   {'account_id': 'XAnVWRprPzf78QaPkd6VIGmJ7aB7J5fdmjJ49',
#    'account_owner': None,
#    'amount': 500,
#    'category': ['Shops', 'Sporting Goods'],
#    'category_id': '19046000',
#    'date': '2019-07-29',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'Madison Bicycle Shop',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': 'MQMNDV9PqEFrzJVZ6BdkcnNbxk1JraC9JpkNv',
#    'transaction_type': 'place',
#    'unofficial_currency_code': None},
#   {'account_id': 'RpgyDAJG3RhdpVneL6m8ceymLBJLmMFRgkMKG',
#    'account_owner': None,
#    'amount': 25,
#    'category': ['Payment', 'Credit Card'],
#    'category_id': '16001000',
#    'date': '2019-07-20',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'CREDIT CARD 3333 PAYMENT *//',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': 'x8VWnmLKlEhzGqb5jvnxclmk3Re7qDtn3Pgy5',
#    'transaction_type': 'special',
#    'unofficial_currency_code': None},
#   {'account_id': 'voVWnJblXpfKylGrwXoASV13BpaB3JfWMeJjn',
#    'account_owner': None,
#    'amount': 5.4,
#    'category': ['Travel', 'Car Service', 'Ride Share'],
#    'category_id': '22006001',
#    'date': '2019-07-20',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'Uber 063015 SF**POOL**',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': 'QLoGDAQZB9TxrQBJdDbghRdEoz5a7jCp56BwZ',
#    'transaction_type': 'special',
#    'unofficial_currency_code': None},
#   {'account_id': 'DkazDGKB7xfbVdo7nxpXU5mDqrNqD8uv5RdgZ',
#    'account_owner': None,
#    'amount': 5850,
#    'category': ['Transfer', 'Debit'],
#    'category_id': '21006000',
#    'date': '2019-07-19',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'ACH Electronic CreditGUSTO PAY 123456',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': 'ACH',
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': 'BBxKbWNkPrHjdZ91KqvAszG6JeNXlMuwb5akx',
#    'transaction_type': 'special',
#    'unofficial_currency_code': None},
#   {'account_id': '6GWbE4JvlotAlJMRGPwXs9alrN8rl3ugBKkWG',
#    'account_owner': None,
#    'amount': 1000,
#    'category': ['Transfer', 'Deposit'],
#    'category_id': '21007000',
#    'date': '2019-07-19',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'CD DEPOSIT .INITIAL.',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': 'mjVXnwWAyrI6ZL14BDnVuAbzDqkmeWCLDpkMm',
#    'transaction_type': 'special',
#    'unofficial_currency_code': None},
#   {'account_id': 'XAnVWRprPzf78QaPkd6VIGmJ7aB7J5fdmjJ49',
#    'account_owner': None,
#    'amount': 78.5,
#    'category': ['Recreation', 'Gyms and Fitness Centers'],
#    'category_id': '17018000',
#    'date': '2019-07-18',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'Touchstone Climbing',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': 'ZnVyWAwB7dHQpylX1NrEsqblLoBxJgIg6mWPL',
#    'transaction_type': 'place',
#    'unofficial_currency_code': None},
#   {'account_id': 'voVWnJblXpfKylGrwXoASV13BpaB3JfWMeJjn',
#    'account_owner': None,
#    'amount': -500,
#    'category': ['Travel', 'Airlines and Aviation Services'],
#    'category_id': '22001000',
#    'date': '2019-07-18',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'United Airlines',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': 'eBVxWD4wEbHPl3NAyq6nUQDN3L4GZXHL4BPrE',
#    'transaction_type': 'special',
#    'unofficial_currency_code': None},
#   {'account_id': 'voVWnJblXpfKylGrwXoASV13BpaB3JfWMeJjn',
#    'account_owner': None,
#    'amount': 12,
#    'category': ['Food and Drink', 'Restaurants'],
#    'category_id': '13005000',
#    'date': '2019-07-17',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': '3322'},
#    'name': "McDonald's",
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': 'j4Vmn637Ewh71MQN5mrdIdPqE5VMDWc1Vm96Z',
#    'transaction_type': 'place',
#    'unofficial_currency_code': None},
#   {'account_id': 'voVWnJblXpfKylGrwXoASV13BpaB3JfWMeJjn',
#    'account_owner': None,
#    'amount': 4.33,
#    'category': ['Food and Drink', 'Restaurants', 'Coffee Shop'],
#    'category_id': '13005043',
#    'date': '2019-07-17',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'Starbucks',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': '7nA5DNvXq8HAoQKRZBz5sVR5r1Jwyxfgoy3d1',
#    'transaction_type': 'place',
#    'unofficial_currency_code': None},
#   {'account_id': 'voVWnJblXpfKylGrwXoASV13BpaB3JfWMeJjn',
#    'account_owner': None,
#    'amount': 89.4,
#    'category': ['Food and Drink', 'Restaurants'],
#    'category_id': '13005000',
#    'date': '2019-07-16',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'SparkFun',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': 'P1pZDAR7zmh3pE6XJw1eHzjGdy9BgPu7P5joX',
#    'transaction_type': 'place',
#    'unofficial_currency_code': None},
#   {'account_id': 'RpgyDAJG3RhdpVneL6m8ceymLBJLmMFRgkMKG',
#    'account_owner': None,
#    'amount': -4.22,
#    'category': ['Transfer', 'Credit'],
#    'category_id': '21005000',
#    'date': '2019-07-15',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'INTRST PYMNT',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': 'pQVRnmbAwaFkgJo4ed1bU7mvZAlrW5hLZjeJy',
#    'transaction_type': 'special',
#    'unofficial_currency_code': None},
#   {'account_id': 'XAnVWRprPzf78QaPkd6VIGmJ7aB7J5fdmjJ49',
#    'account_owner': None,
#    'amount': 500,
#    'category': ['Travel', 'Airlines and Aviation Services'],
#    'category_id': '22001000',
#    'date': '2019-07-05',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'United Airlines',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': 'QLoGDAQZB9TxrQBJdDbghRdEoz5a7jCp56BZM',
#    'transaction_type': 'special',
#    'unofficial_currency_code': None},
#   {'account_id': 'voVWnJblXpfKylGrwXoASV13BpaB3JfWMeJjn',
#    'account_owner': None,
#    'amount': 6.33,
#    'category': ['Travel', 'Car Service', 'Ride Share'],
#    'category_id': '22006001',
#    'date': '2019-07-03',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'Uber 072515 SF**POOL**',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': 'NZ1jDyVPKAHzEB9VKaGncrDmZ1qMw4uW4payy',
#    'transaction_type': 'special',
#    'unofficial_currency_code': None}]}

# %%
# Output to file
# import csv
# w = csv.writer(open('transaction_response.csv', "w"))
# for key, val in transaction_response.items():
#     w.writerow([key, val])

# %% [markdown]
# ### 2. Print the categories for each transaction

# %%
# YOUR CODE HERE
for transactions in transaction_response['transactions']:
    print(transactions['category'])
# Out:
# ['Food and Drink', 'Restaurants']
# ['Payment']
# ['Food and Drink', 'Restaurants']
# ['Shops', 'Sporting Goods']
# ['Payment', 'Credit Card']
# ['Travel', 'Car Service', 'Ride Share']
# ['Transfer', 'Debit']
# ['Transfer', 'Deposit']
# ['Recreation', 'Gyms and Fitness Centers']
# ['Travel', 'Airlines and Aviation Services']
# ['Food and Drink', 'Restaurants']
# ['Food and Drink', 'Restaurants', 'Coffee Shop']
# ['Food and Drink', 'Restaurants']
# ['Transfer', 'Credit']
# ['Travel', 'Airlines and Aviation Services']
# ['Travel', 'Car Service', 'Ride Share']
# ['Food and Drink', 'Restaurants']
# ['Payment']
# ['Food and Drink', 'Restaurants']
# ['Shops', 'Sporting Goods']
# ['Payment', 'Credit Card']
# ['Travel', 'Car Service', 'Ride Share']
# ['Transfer', 'Debit']
# ['Transfer', 'Deposit']
# ['Recreation', 'Gyms and Fitness Centers']
# ['Travel', 'Airlines and Aviation Services']
# ['Food and Drink', 'Restaurants']
# ['Food and Drink', 'Restaurants', 'Coffee Shop']
# ['Food and Drink', 'Restaurants']
# ['Transfer', 'Credit']
# ['Travel', 'Airlines and Aviation Services']
# ['Travel', 'Car Service', 'Ride Share']
# ['Food and Drink', 'Restaurants']
# ['Payment']
# ['Food and Drink', 'Restaurants']
# ['Shops', 'Sporting Goods']
# ['Payment', 'Credit Card']
# ['Travel', 'Car Service', 'Ride Share']
# ['Transfer', 'Debit']
# ['Transfer', 'Deposit']
# ['Recreation', 'Gyms and Fitness Centers']
# ['Travel', 'Airlines and Aviation Services']
# ['Food and Drink', 'Restaurants']
# ['Food and Drink', 'Restaurants', 'Coffee Shop']
# ['Food and Drink', 'Restaurants']
# ['Transfer', 'Credit']
# ['Travel', 'Airlines and Aviation Services']
# ['Travel', 'Car Service', 'Ride Share']

# %% [markdown]
# ### 3. Create a new DataFrame using the following fields from the JSON transaction data: date, name, amount, category.
#
# (For categories with more than one label, just use the first category label in the list)

# %%
# YOUR CODE HERE
del new_df
cols = ['date', 'name', 'amount', 'category']

new_df = pd.DataFrame(transaction_response['transactions'], columns = cols)        
new_df['category'] = df2['category'].str[0]
new_df.head()
new_df.dtypes
# new_df.index
# Out:
# date         object
# name         object
# amount      float64
# category     object
# dtype: object

# %% [markdown]
# ### 4. Convert the data types to the appropriate types
#
# (i.e. datetimeindex for the date and float for the amount)

# %%
# YOUR CODE HERE
# Setting the datetime index
new_df['date'] =  pd.to_datetime(new_df['date'])
# new_df.set_index('date', inplace = True, drop = False)
new_df.dtypes
new_df.head()
# Out:
#         date                          name  amount        category
# 0 2019-09-28                    Tectra Inc   500.0  Food and Drink
# 1 2019-09-27     AUTOMATIC PAYMENT - THANK  2078.5         Payment
# 2 2019-09-27                           KFC   500.0  Food and Drink
# 3 2019-09-27          Madison Bicycle Shop   500.0           Shops
# 4 2019-09-18  CREDIT CARD 3333 PAYMENT *//    25.0         Payment

# %% [markdown]
# ---

# %% [markdown]
# # Income Analysis with Plaid
#
# In this section, you will use the Plaid Sandbox to complete the following:
# 1. Determine the previous year's gross income and print the results
# 2. Determine the current monthly income and print the results
# 3. Determine the projected yearly income and print the results

# %%
# YOUR CODE HERE
new_df['year'] = pd.DatetimeIndex(new_df['date']).year
new_df['month'] = pd.DatetimeIndex(new_df['date']).month

# Discovery
new_df.head()
new_df['year'].max()

# Prior year gross income
new_prior_year_df = new_df[new_df['year'] == 2018]
new_prior_year_df

# Current monthly income
new_df.loc[new_df['month'] == 9, 'amount'].sum()

# Projected yearly income
new_df.loc[new_df['year'] == 2019, 'amount'].mean()*12
# Out:
# 7983.930000000002

# %% [markdown]
# # Budget Analysis
# In this section, you will use the transactions DataFrame to analyze the customer's budget
#
# 1. Calculate the total spending per category and print the results (Hint: groupby or count transactions per category)
# 2. Generate a bar chart with the number of transactions for each category
# 3. Calulate the expenses per month
# 4. Plot the total expenses per month

# %% [markdown]
# ### Calculate the expenses per category

# %%
# YOUR CODE HERE
# print(tabulate(expenses_per_category, headers = ["Category", "Amount"],numalign="right",floatfmt=".2f",tablefmt="pipe"))

# Expenses per category
new_category_df = new_df.groupby(['category']).sum()
new_category_df.head()
new_category_df.reset_index(inplace = True)
new_category_df.head()

# Bar chart of Transactions per category
new_category_df[['category','amount']].plot(kind='bar', title ="Expenses per category", figsize=(25, 10), legend=True, fontsize=12)

# %% [markdown]
# ### Calculate the expenses per month

# %%
# YOUR CODE HERE
# Expenses per month
new_month_df = new_df.groupby(['month']).sum()
new_month_df.head()
new_month_df.reset_index(inplace = True)
new_month_df.head()

# Plot of expenses per month
new_month_df[['month','amount']].plot(kind='bar', title ="Expenses per month", figsize=(25, 10), legend=True, fontsize=12)
